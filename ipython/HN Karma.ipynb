# %% [markdown]
# # Hacker News Karma Document

# %% [markdown]
# ## Setup

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 1

# %%
import sys
sys.path.append("/Users/tdimson/personal/cs224w-karma-prediction/src/python")
HN_DB_FILE = "/Users/tdimson/personal/cs224w-karma-prediction/data/hn.db"

# %%
import matplotlib.pyplot as plt
import numpy as np

from util import xs, ys

# %%
# %aimport hn_karma

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### Karma Distribution

# %%
user_distribution = hn_karma.compute_user_karma_distribution(HN_DB_FILE)

# %%
plt.figure(figsize=(12,6))
plt.title("User Karma Distribution on Hacker News")
plt.loglog(xs(user_distribution), ys(user_distribution), 'r')
